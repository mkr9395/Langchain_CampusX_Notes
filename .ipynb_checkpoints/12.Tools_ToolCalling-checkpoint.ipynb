# %% [markdown]
# # SESSION 18 : Tools in LangChain | Generative AI using LangChain | Video 16

# %% [markdown]
# https://youtu.be/etnLX7m2MiA?list=PLKnIA16_RmvaTbihpo4MtzVm4XOQa0ER0

# %% [markdown]
# ![Screenshot%202025-08-27%20133536.png](attachment:Screenshot%202025-08-27%20133536.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### What is a Tool?

# %% [markdown]
# A tool is just a Python function (or API) that is packaged in a way the LLM can understand and call when needed.

# %% [markdown]
# #### Types of tools :

# %% [markdown]
# ![Screenshot%202025-08-27%20133653.png](attachment:Screenshot%202025-08-27%20133653.png)

# %% [markdown]
# ### How Tools fits into the Agent ecosystem

# %% [markdown]
# An AI agent is an LLM-powered system that can autonomously think, decide, and take actions using external tools or APIs to achieve a goal.
#
#
# - __Reasoning and Decision Making__ is done by the LLM
#
#
# - Action is taken by the __Tools__

# %% [markdown]
# ![Screenshot%202025-08-27%20133738.png](attachment:Screenshot%202025-08-27%20133738.png)

# %% [markdown]
# ### Built-in Tools

# %% [markdown]
# A built-in tool is a tool that LangChain already provides for you —it’s pre-built, productionready, and requires minimal or no setup.
#
#
# You don’t have to write the function logic yourself — you just import and use it.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Custom Tools

# %% [markdown]
# A custom tool is a tool that you define yourself.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ways to create Custom Tools

# %% [markdown]
# ![Screenshot%202025-08-27%20145155.png](attachment:Screenshot%202025-08-27%20145155.png)

# %% [markdown]
# 2. A __Structured Tool__ in LangChain is a special type of tool where the input to the tool follows a structured schema, typically defined __using a Pydantic model.__

# %% [markdown]
# 3. __BaseTool__ is the abstract base class for all tools in LangChain. It defines the core structure and interface that any tool must follow, whether it's a simple one-liner or a fully customized function.
#
#
# All other tool types like __@tool, StructuredTool__ are built on top of BaseTool

# %% [markdown]
# ### Toolkits

# %% [markdown]
# A toolkit is just a collection (bundle) of related tools that serve a common purpose — packaged together for convenience and reusability.
#
#
# #### In LangChain:
#
# - A toolkit might be: GoogleDriveToolKit
#
#
# - And it can contain the following tools

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # SESSION 19 : Tool Calling in LangChain | Generative AI using LangChain | Video 17

# %% [markdown]
# https://youtu.be/EzYaFF7ahKw?list=PLKnIA16_RmvaTbihpo4MtzVm4XOQa0ER0
